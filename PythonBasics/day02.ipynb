# %%
#判断语句-if
bool1 = False
bool2 = True
bool3 = False
if bool1:
    print(1)
elif bool2:
    print(2)
elif bool3:
    print(3)
else:
    print('“全部不满足”')
# Out:
# 2

# %%
bool1 = False
bool2 = False
bool3 = False
if bool1:
    print(1)
elif bool2:
    print(2)
elif bool3:
    print(3)
else:
    print('“全部不满足”')
# Out:
# “全部不满足”

# %%
answer = 91
if answer>90:
    print('A')
elif answer>80:
    print('B')
elif answer>=60:
    print('pass')
else:
    print('fail to exam')

answer = 81
if answer>90:
    print('A')
elif answer>80:
    print('B')
elif answer>=60:
    print('pass')
else:
    print('fail to exam')

answer = 61
if answer>90:
    print('A')
elif answer>80:
    print('B')
elif answer>=60:
    print('pass')
else:
    print('fail to exam')

answer = 59
if answer>90:
    print('A')
elif answer>80:
    print('B')
elif answer>=60:
    print('pass')
else:
    print('fail to exam')
# Out:
# A
# B
# pass
# fail to exam
